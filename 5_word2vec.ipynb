# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'a', 'originated', 'as', 'term', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['term', 'originated', 'a', 'anarchism', 'term', 'originated', 'as', 'of']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.909472
# Nearest to some: gmbh, refurbished, bourne, acr, encompassed, immoral, erbium, slashed,
# Nearest to over: producers, marcello, pneumonia, confederate, significantly, inr, bpm, veered,
# Nearest to often: kowtow, forgetfulness, kindergarten, darnley, hawkwind, exemplifies, understated, agile,
# Nearest to which: how, mee, prismatic, shulkhan, mrs, olympia, parentheses, residual,
# Nearest to have: gtk, nerve, timaeus, couturat, fell, margarine, geisel, wyman,
# Nearest to are: giraffe, anand, index, opponent, thou, pett, rides, max,
# Nearest to when: gypsy, overbeck, completing, mailboxes, offsets, mashiach, emissaries, argumentation,
# Nearest to is: roberto, seize, rumour, multicellular, beauvoir, messalina, hawkwind, beatrice,
# Nearest to and: diger, answer, cogency, tyranny, diatomaceous, anime, equivocation, kristallnacht,
# Nearest to be: fremont, absurdities, austral, martov, cantonal, generalities, zappa, offutt,
# Nearest to time: stare, slightest, entails, moguls, seismic, empresses, celtic, nickname,
# Nearest to one: councilor, populist, executables, parishes, duke, wary, papers, amiable,
# Nearest to i: poked, cherry, snakes, frogs, springfield, gentler, fascist, myspace,
# Nearest to american: thoroughfares, ern, cartagena, mana, sof, heorot, gunn, dialects,
# Nearest to had: braille, pyrite, hibernation, pyrotechnics, deviating, alamos, flops, laotian,
# Nearest to this: rzburg, augustan, horizonte, schwerin, castrato, anachronisms, unsophisticated, stymied,
# Average loss at step 2000: 4.367678
# Average loss at step 4000: 3.870843
# Average loss at step 6000: 3.786543
# Average loss at step 8000: 3.678789
# Average loss at step 10000: 3.614347
# Nearest to some: many, different, refurbished, doughnut, orientation, stripes, opposing, goidelic,
# Nearest to over: inr, confederate, bpm, significantly, pneumonia, producers, term, veered,
# Nearest to often: also, sometimes, not, kowtow, there, kindergarten, forgetfulness, harrow,
# Nearest to which: that, also, how, this, it, mrs, generously, founded,
# Nearest to have: had, has, be, were, are, instructed, cogency, espousing,
# Nearest to are: were, is, have, was, replenished, providers, favourable, messerschmitt,
# Nearest to when: argumentation, hybridization, mashiach, overbeck, gypsy, mena, completing, dea,
# Nearest to is: was, are, has, be, transcendentalism, sepsis, exclaims, but,
# Nearest to and: or, in, s, he, of, who, american, resonance,
# Nearest to be: have, was, been, is, lead, offutt, are, by,
# Nearest to time: rahilly, ordain, anarcho, stare, cliff, msn, explorer, celtic,
# Nearest to one: three, two, six, eight, kilgore, four, five, seven,
# Nearest to i: we, prague, gentler, snakes, poked, html, paxton, coleman,
# Nearest to american: tiu, and, omitting, ninth, app, teletype, mccormick, mana,
# Nearest to had: have, has, was, were, pyrite, postpositions, chuvash, replay,
# Nearest to this: it, the, that, which, disaccharides, a, joining, dials,
# Average loss at step 12000: 3.605830
# Average loss at step 14000: 3.563852
# Average loss at step 16000: 3.410129
# Average loss at step 18000: 3.457015
# Average loss at step 20000: 3.539690
# Nearest to some: many, all, refurbished, these, their, most, his, the,
# Nearest to over: pneumonia, significantly, term, inr, persian, marcello, biathletes, ee,
# Nearest to often: also, sometimes, kindergarten, who, which, not, there, still,
# Nearest to which: that, this, also, it, there, who, but, often,
# Nearest to have: had, has, be, were, are, phrasing, escherichia, espousing,
# Nearest to are: were, is, have, was, while, hologram, but, though,
# Nearest to when: if, mashiach, before, hybridization, gypsy, pictorial, consultations, with,
# Nearest to is: was, has, are, transcendentalism, mishnayot, does, single, amateur,
# Nearest to and: or, kristallnacht, in, parsers, ghibellines, ornamented, but, psi,
# Nearest to be: have, been, was, refuse, become, being, by, refer,
# Nearest to time: robot, rahilly, ordain, anarcho, course, irt, cipher, year,
# Nearest to one: three, two, four, six, seven, eight, five, nine,
# Nearest to i: we, ii, you, psychopathic, dravidian, html, prague, aceh,
# Nearest to american: british, mccormick, australian, tres, ness, omitting, tiu, national,
# Nearest to had: has, have, were, was, would, pyrite, having, chuvash,
# Nearest to this: it, which, the, disaccharides, a, another, that, orientation,
# Average loss at step 22000: 3.499816
# Average loss at step 24000: 3.485415
# Average loss at step 26000: 3.483558
# Average loss at step 28000: 3.480789
# Average loss at step 30000: 3.506625
# Nearest to some: many, these, several, all, any, other, the, refurbished,
# Nearest to over: imf, inr, term, cramer, ee, pneumonia, pied, into,
# Nearest to often: sometimes, also, usually, commonly, still, there, who, kindergarten,
# Nearest to which: this, that, also, it, but, there, these, who,
# Nearest to have: had, has, were, are, be, escherichia, provide, toon,
# Nearest to are: were, is, have, these, be, other, nasir, but,
# Nearest to when: if, before, after, but, mashiach, while, where, under,
# Nearest to is: was, has, are, be, were, transcendentalism, does, being,
# Nearest to and: or, but, in, andechs, motile, etonians, including, while,
# Nearest to be: been, have, is, refuse, are, was, were, become,
# Nearest to time: robot, ordain, year, hilly, course, nativity, cipher, irt,
# Nearest to one: two, seven, four, three, six, eight, five, nine,
# Nearest to i: ii, we, you, himmel, atiyah, coleman, they, denies,
# Nearest to american: british, english, australian, mccormick, russian, tres, italian, national,
# Nearest to had: have, has, was, were, since, saw, never, would,
# Nearest to this: it, which, there, that, what, some, dials, the,
# Average loss at step 32000: 3.501686
# Average loss at step 34000: 3.494177
# Average loss at step 36000: 3.450185
# Average loss at step 38000: 3.302654
# Average loss at step 40000: 3.427865
# Nearest to some: many, these, several, any, this, their, most, the,
# Nearest to over: motile, inr, economically, into, significantly, overall, since, pied,
# Nearest to often: sometimes, usually, also, still, generally, commonly, which, who,
# Nearest to which: that, this, there, it, also, who, often, usually,
# Nearest to have: had, has, were, be, are, provide, favors, never,
# Nearest to are: were, have, is, be, these, but, disengage, although,
# Nearest to when: if, while, before, where, reine, after, once, since,
# Nearest to is: was, are, has, be, if, transcendentalism, condom, viridis,
# Nearest to and: or, but, in, including, mika, diatomaceous, charleroi, if,
# Nearest to be: been, have, is, refuse, was, were, are, astonishingly,
# Nearest to time: year, jesse, ordain, robot, day, way, irt, years,
# Nearest to one: seven, eight, two, four, six, five, three, nine,
# Nearest to i: we, ii, you, he, they, himmel, aikidoka, she,
# Nearest to american: british, english, russian, german, australian, italian, tres, french,
# Nearest to had: has, have, was, were, since, would, rana, postpositions,
# Nearest to this: which, it, the, that, any, some, there, he,
# Average loss at step 42000: 3.436471
# Average loss at step 44000: 3.453605
# Average loss at step 46000: 3.452653
# Average loss at step 48000: 3.355252
# Average loss at step 50000: 3.381014
# Nearest to some: many, these, several, various, most, this, their, other,
# Nearest to over: imf, into, economically, biathletes, motile, on, freethought, pied,
# Nearest to often: sometimes, usually, generally, commonly, also, still, now, which,
# Nearest to which: that, this, also, often, who, but, what, usually,
# Nearest to have: had, has, were, be, are, instructed, never, provide,
# Nearest to are: were, is, have, these, be, although, disengage, was,
# Nearest to when: if, while, before, after, where, since, but, once,
# Nearest to is: was, has, are, be, transcendentalism, became, vegeta, were,
# Nearest to and: or, but, while, including, of, solf, wording, in,
# Nearest to be: have, was, refuse, were, is, been, become, refer,
# Nearest to time: year, way, day, pogroms, ordain, jesse, embellishment, shevat,
# Nearest to one: two, seven, six, eight, four, three, five, nine,
# Nearest to i: ii, we, you, they, he, biham, she, intrigue,
# Nearest to american: english, tres, british, australian, italian, russian, mccormick, french,
# Nearest to had: has, have, was, were, having, been, rana, recovers,
# Nearest to this: which, it, the, some, there, dials, he, that,
# Average loss at step 52000: 3.438893
# Average loss at step 54000: 3.423970
# Average loss at step 56000: 3.438031
# Average loss at step 58000: 3.393794
# Average loss at step 60000: 3.396137
# Nearest to some: many, several, these, any, all, most, their, this,
# Nearest to over: into, through, imf, soliciting, pied, motile, overall, persian,
# Nearest to often: usually, sometimes, commonly, generally, now, also, still, typically,
# Nearest to which: that, this, what, who, it, these, singularities, but,
# Nearest to have: has, had, were, are, provide, be, having, include,
# Nearest to are: were, is, have, be, although, include, including, these,
# Nearest to when: if, while, although, after, before, but, where, because,
# Nearest to is: was, are, has, although, but, does, be, transcendentalism,
# Nearest to and: or, but, smash, although, including, than, however, matthias,
# Nearest to be: been, refuse, become, have, are, was, refer, is,
# Nearest to time: year, way, pogroms, day, jesse, robot, lieutenants, ordain,
# Nearest to one: six, eight, seven, two, four, five, nine, three,
# Nearest to i: ii, we, you, they, biham, he, intrigue, centrality,
# Nearest to american: english, tres, australian, russian, british, italian, german, disassembled,
# Nearest to had: has, have, was, were, having, recovers, been, subsequently,
# Nearest to this: which, it, there, the, some, what, that, attacker,
# Average loss at step 62000: 3.240370
# Average loss at step 64000: 3.258020
# Average loss at step 66000: 3.401063
# Average loss at step 68000: 3.396514
# Average loss at step 70000: 3.360254
# Nearest to some: many, several, all, these, various, most, any, their,
# Nearest to over: into, motile, around, imf, off, economically, tomcats, overall,
# Nearest to often: sometimes, usually, commonly, generally, now, frequently, still, typically,
# Nearest to which: that, this, but, also, what, and, these, it,
# Nearest to have: had, has, were, provide, having, are, include, be,
# Nearest to are: were, is, although, have, these, include, those, be,
# Nearest to when: if, while, where, before, after, however, although, but,
# Nearest to is: was, has, are, be, transcendentalism, although, seems, being,
# Nearest to and: or, but, which, smash, while, like, than, sickly,
# Nearest to be: been, is, refuse, become, were, have, refer, astonishingly,
# Nearest to time: year, way, robot, course, ordain, pogroms, thing, fascism,
# Nearest to one: two, six, seven, eight, four, five, nine, three,
# Nearest to i: ii, we, you, they, iii, g, he, biham,
# Nearest to american: english, british, australian, tres, italian, disassembled, mccormick, apollodorus,
# Nearest to had: have, has, was, were, having, been, recovers, saw,
# Nearest to this: which, it, the, that, there, itself, some, another,
# Average loss at step 72000: 3.374333
# Average loss at step 74000: 3.347694
# Average loss at step 76000: 3.319413
# Average loss at step 78000: 3.357955
# Average loss at step 80000: 3.380016
# Nearest to some: many, several, most, various, these, all, certain, any,
# Nearest to over: into, around, motile, off, through, duct, imf, inr,
# Nearest to often: sometimes, usually, generally, commonly, typically, now, still, frequently,
# Nearest to which: that, this, also, but, who, usually, what, daytime,
# Nearest to have: had, has, be, having, were, are, include, provide,
# Nearest to are: were, although, have, is, include, those, while, be,
# Nearest to when: if, before, after, where, although, during, while, though,
# Nearest to is: was, has, are, became, although, be, does, transcendentalism,
# Nearest to and: or, but, while, including, eulemur, humbucker, diatomaceous, although,
# Nearest to be: been, have, refuse, become, being, afford, refer, astonishingly,
# Nearest to time: year, thing, robot, lieutenants, jesse, beatified, ordain, hollandic,
# Nearest to one: seven, six, two, four, three, eight, five, nine,
# Nearest to i: ii, we, iii, you, g, they, iv, biham,
# Nearest to american: british, australian, italian, english, german, french, russian, tres,
# Nearest to had: have, has, were, having, was, wanted, been, natalia,
# Nearest to this: which, it, that, the, itself, some, there, attacker,
# Average loss at step 82000: 3.406477
# Average loss at step 84000: 3.411335
# Average loss at step 86000: 3.392028
# Average loss at step 88000: 3.351961
# Average loss at step 90000: 3.365230
# Nearest to some: many, several, these, any, all, certain, most, those,
# Nearest to over: through, motile, into, off, around, pretensions, without, lightly,
# Nearest to often: sometimes, usually, generally, commonly, frequently, now, typically, still,
# Nearest to which: that, this, what, also, itself, usually, but, often,
# Nearest to have: had, has, were, having, are, be, tend, provide,
# Nearest to are: were, is, include, have, although, these, heidi, pastry,
# Nearest to when: if, before, after, while, where, although, until, during,
# Nearest to is: was, has, are, although, be, became, does, contains,
# Nearest to and: or, but, while, diatomaceous, including, of, alley, desiderius,
# Nearest to be: been, refuse, become, lead, astonishingly, was, is, afford,
# Nearest to time: year, robot, thing, balkh, course, way, cases, ordain,
# Nearest to one: seven, four, two, eight, six, five, three, nine,
# Nearest to i: ii, we, iii, g, you, iv, mail, they,
# Nearest to american: british, australian, italian, french, german, russian, english, tres,
# Nearest to had: has, have, was, were, having, began, natalia, since,
# Nearest to this: which, it, itself, some, the, another, what, consisting,
# Average loss at step 92000: 3.394237
# Average loss at step 94000: 3.255226
# Average loss at step 96000: 3.358663
# Average loss at step 98000: 3.244469
# Average loss at step 100000: 3.357564
# Nearest to some: many, these, several, any, certain, this, all, various,
# Nearest to over: through, pmod, motile, into, around, within, lightly, off,
# Nearest to often: sometimes, usually, generally, commonly, typically, frequently, now, still,
# Nearest to which: that, this, what, usually, who, it, also, however,
# Nearest to have: had, has, were, having, be, are, include, contain,
# Nearest to are: were, have, is, these, include, although, patchwork, be,
# Nearest to when: if, while, where, after, although, before, though, during,
# Nearest to is: was, has, became, are, transcendentalism, be, does, contains,
# Nearest to and: or, but, including, although, who, desiderius, than, however,
# Nearest to be: been, refuse, have, afford, become, being, refer, is,
# Nearest to time: year, thing, robot, balkh, way, beatified, course, evidence,
# Nearest to one: two, four, seven, three, six, eight, five, nine,
# Nearest to i: we, ii, you, iii, mail, they, he, she,
# Nearest to american: british, italian, australian, english, canadian, german, richard, french,
# Nearest to had: has, have, was, having, were, natalia, would, recovers,
# Nearest to this: which, it, some, another, what, itself, the, kyoto,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---
